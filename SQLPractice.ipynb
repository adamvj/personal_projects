# %%
# !mysql < sakila/sakila-database.sql

# %%
# !mysql < sakila/sakila-data.sql

# %%
# !mysql -e "SELECT COUNT(*) FROM actor" sakila
# Out:
# +----------+
# | COUNT(*) |
# +----------+
# |      200 |
# +----------+

# %%
# !mysql -e "SELECT COUNT(*) FROM address" sakila
# Out:
# +----------+
# | COUNT(*) |
# +----------+
# |      603 |
# +----------+

# %%
# !mysql -e "SELECT COUNT(*) FROM film" sakila
# Out:
# +----------+
# | COUNT(*) |
# +----------+
# |     1000 |
# +----------+

# %%
# !mysql -e "SELECT COUNT(*) FROM payment" sakila
# Out:
# +----------+
# | COUNT(*) |
# +----------+
# |    16049 |
# +----------+

# %%
# !mysql -e "SELECT COUNT(*) FROM city" sakila
# Out:
# +----------+
# | COUNT(*) |
# +----------+
# |      600 |
# +----------+

# %%
# !mysql sakila -e  "SELECT payment_id, customer_id, amount FROM payment LIMIT 5"
# Out:
# +------------+-------------+--------+
# | payment_id | customer_id | amount |
# +------------+-------------+--------+
# |          1 |           1 |   2.99 |
# |          2 |           1 |   0.99 |
# |          3 |           1 |   5.99 |
# |          4 |           1 |   0.99 |
# |          5 |           1 |   9.99 |
# +------------+-------------+--------+

# %%
# !mysql sakila -e "SELECT actor_id, first_name, last_name FROM actor LIMIT 5"
# Out:
# +----------+------------+--------------+
# | actor_id | first_name | last_name    |
# +----------+------------+--------------+
# |        1 | PENELOPE   | GUINESS      |
# |        2 | NICK       | WAHLBERG     |
# |        3 | ED         | CHASE        |
# |        4 | JENNIFER   | DAVIS        |
# |        5 | JOHNNY     | LOLLOBRIGIDA |
# +----------+------------+--------------+

# %%
# !mysql sakila -e "SELECT film_id, title, release_year FROM film LIMIT 5;"
# Out:
# +---------+------------------+--------------+
# | film_id | title            | release_year |
# +---------+------------------+--------------+
# |       1 | ACADEMY DINOSAUR |         2006 |
# |       2 | ACE GOLDFINGER   |         2006 |
# |       3 | ADAPTATION HOLES |         2006 |
# |       4 | AFFAIR PREJUDICE |         2006 |
# |       5 | AFRICAN EGG      |         2006 |
# +---------+------------------+--------------+

# %%
# !mysql sakila -e "SELECT customer_id, first_name, last_name FROM customer LIMIT 5;"
# Out:
# +-------------+------------+-----------+
# | customer_id | first_name | last_name |
# +-------------+------------+-----------+
# |           1 | MARY       | SMITH     |
# |           2 | PATRICIA   | JOHNSON   |
# |           3 | LINDA      | WILLIAMS  |
# |           4 | BARBARA    | JONES     |
# |           5 | ELIZABETH  | BROWN     |
# +-------------+------------+-----------+

# %%
# !mysql sakila -e "SELECT rental_id, rental_date, customer_id FROM rental LIMIT 5;"
# Out:
# +-----------+---------------------+-------------+
# | rental_id | rental_date         | customer_id |
# +-----------+---------------------+-------------+
# |         1 | 2005-05-24 22:53:30 |         130 |
# |         2 | 2005-05-24 22:54:33 |         459 |
# |         3 | 2005-05-24 23:03:39 |         408 |
# |         4 | 2005-05-24 23:04:41 |         333 |
# |         5 | 2005-05-24 23:05:21 |         222 |
# +-----------+---------------------+-------------+

# %%
## Query to find films rated PG-13, sorted by ascending order alphabetically 

# !mysql sakila -e "SELECT title, rating, release_year FROM film WHERE rating = 'PG-13' ORDER BY title ASC;"
# Out:
# +-----------------------------+--------+--------------+
# | title                       | rating | release_year |
# +-----------------------------+--------+--------------+
# | AIRPLANE SIERRA             | PG-13  |         2006 |
# | ALABAMA DEVIL               | PG-13  |         2006 |
# | ALTER VICTORY               | PG-13  |         2006 |
# | ANTHEM LUKE                 | PG-13  |         2006 |
# | APOLLO TEEN                 | PG-13  |         2006 |
# | ARACHNOPHOBIA ROLLERCOASTER | PG-13  |         2006 |
# | ARGONAUTS TOWN              | PG-13  |         2006 |
# | ATTACKS HATE                | PG-13  |         2006 |
# | ATTRACTION NEWTON           | PG-13  |         2006 |
# | BACKLASH UNDEFEATED         | PG-13  |         2006 |
# | BASIC EASY                  | PG-13  |         2006 |
# | BEETHOVEN EXORCIST          | PG-13  |         2006 |
# | BERETS AGENT                | PG-13  |         2006 |
# | BILKO ANONYMOUS             | PG-13  |         2006 |
# ...

# %%
## Inserting Adam Jose into actors

# !mysql sakila -e "INSERT INTO actor (first_name, last_name) VALUES ('ADAM', 'JOSE');"

# %%
# !mysql sakila -e "SELECT * FROM actor"
# Out:
# +----------+-------------+--------------+---------------------+
# | actor_id | first_name  | last_name    | last_update         |
# +----------+-------------+--------------+---------------------+
# |        1 | PENELOPE    | GUINESS      | 2006-02-15 04:34:33 |
# |        2 | NICK        | WAHLBERG     | 2006-02-15 04:34:33 |
# |        3 | ED          | CHASE        | 2006-02-15 04:34:33 |
# |        4 | JENNIFER    | DAVIS        | 2006-02-15 04:34:33 |
# |        5 | JOHNNY      | LOLLOBRIGIDA | 2006-02-15 04:34:33 |
# |        6 | BETTE       | NICHOLSON    | 2006-02-15 04:34:33 |
# |        7 | GRACE       | MOSTEL       | 2006-02-15 04:34:33 |
# |        8 | MATTHEW     | JOHANSSON    | 2006-02-15 04:34:33 |
# |        9 | JOE         | SWANK        | 2006-02-15 04:34:33 |
# |       10 | CHRISTIAN   | GABLE        | 2006-02-15 04:34:33 |
# |       11 | ZERO        | CAGE         | 2006-02-15 04:34:33 |
# |       12 | KARL        | BERRY        | 2006-02-15 04:34:33 |
# ...

# %%
#updating actor name from Adam Jose to Adam Smith

# !mysql sakila -e "UPDATE actor SET last_name = 'SMITH' WHERE first_name = 'ADAM' AND last_name = 'JOSE';"

# %%
# !mysql sakila -e "SELECT * FROM actor"
# Out:
# +----------+-------------+--------------+---------------------+
# | actor_id | first_name  | last_name    | last_update         |
# +----------+-------------+--------------+---------------------+
# |        1 | PENELOPE    | GUINESS      | 2006-02-15 04:34:33 |
# |        2 | NICK        | WAHLBERG     | 2006-02-15 04:34:33 |
# |        3 | ED          | CHASE        | 2006-02-15 04:34:33 |
# |        4 | JENNIFER    | DAVIS        | 2006-02-15 04:34:33 |
# |        5 | JOHNNY      | LOLLOBRIGIDA | 2006-02-15 04:34:33 |
# |        6 | BETTE       | NICHOLSON    | 2006-02-15 04:34:33 |
# |        7 | GRACE       | MOSTEL       | 2006-02-15 04:34:33 |
# |        8 | MATTHEW     | JOHANSSON    | 2006-02-15 04:34:33 |
# |        9 | JOE         | SWANK        | 2006-02-15 04:34:33 |
# |       10 | CHRISTIAN   | GABLE        | 2006-02-15 04:34:33 |
# |       11 | ZERO        | CAGE         | 2006-02-15 04:34:33 |
# |       12 | KARL        | BERRY        | 2006-02-15 04:34:33 |
# ...

# %%
#delelted duplicate Adam Smith by actor_id

# !mysql sakila -e "DELETE FROM actor WHERE actor_id = 203;"

# %%
# !mysql sakila -e "SELECT * FROM actor;"
# Out:
# +----------+-------------+--------------+---------------------+
# | actor_id | first_name  | last_name    | last_update         |
# +----------+-------------+--------------+---------------------+
# |        1 | PENELOPE    | GUINESS      | 2006-02-15 04:34:33 |
# |        2 | NICK        | WAHLBERG     | 2006-02-15 04:34:33 |
# |        3 | ED          | CHASE        | 2006-02-15 04:34:33 |
# |        4 | JENNIFER    | DAVIS        | 2006-02-15 04:34:33 |
# |        5 | JOHNNY      | LOLLOBRIGIDA | 2006-02-15 04:34:33 |
# |        6 | BETTE       | NICHOLSON    | 2006-02-15 04:34:33 |
# |        7 | GRACE       | MOSTEL       | 2006-02-15 04:34:33 |
# |        8 | MATTHEW     | JOHANSSON    | 2006-02-15 04:34:33 |
# |        9 | JOE         | SWANK        | 2006-02-15 04:34:33 |
# |       10 | CHRISTIAN   | GABLE        | 2006-02-15 04:34:33 |
# |       11 | ZERO        | CAGE         | 2006-02-15 04:34:33 |
# |       12 | KARL        | BERRY        | 2006-02-15 04:34:33 |
# ...
